# %%
# !pip install -q matplotlib numpy scipy

# %%
# !git clone https://github.com/MoeenUddin01/breast-cancer-mias.git /kaggle/working/breast-cancer-mias 2>/dev/null || (cd /kaggle/working/breast-cancer-mias && git pull)

# %%
import gc
gc.collect()

# %%
import os
import sys

os.chdir("/kaggle/working/breast-cancer-mias")
sys.path.insert(0, "/kaggle/working/breast-cancer-mias")

# Run the research figures script
exec(open("research_figures.py").read(), globals())
